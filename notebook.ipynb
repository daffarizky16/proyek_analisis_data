# %% [markdown]
# # Proyek Analisis Data: [[E-Commerce Public Dataset](https://drive.google.com/file/d/1MsAjPM7oKtVfJL_wRp1qmCajtSG1mdcK/view) [[Sumber](https://www.kaggle.com/datasets/olistbr/brazilian-ecommerce)]]
# - **Nama:** [Daffa Rizky]
# - **Email:** [daffar315@gmail.com]
# - **ID Dicoding:** [daffarizky]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana Daffline bisa menjadi pasar terbesar di brazil?
# - Pelanggan yang berasal dari wilayah bagian mana yang mendominasi pasar Daffline?
# - Berapa keuntungan yang didapat dari Daffline?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
#Memuat tabel customers
customers_df = pd.read_csv(r"E-Commerce Public Dataset/customers_dataset.csv")
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
#Memuat tabel orders

orders_df = pd.read_csv(r"E-Commerce Public Dataset/orders_dataset.csv")
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
#Memuat tabel product

product_df = pd.read_csv(r"E-Commerce Public Dataset/products_dataset.csv")
product_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
#Memuat tabel sales

sales_df = pd.read_csv(r"E-Commerce Public Dataset/order_items_dataset.csv")
sales_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %% [markdown]
# **Insight:**
# - Berdasarkan hasil analisa gathering data, proyek data ini berisi data-data dari masing-masing tabel yang mana akan membantu nantinya dalam proses selanjutnya
# - Gathering data memudahkan dalam melihat data-data apa saja nanti yang akan dibutuhkan

# %% [markdown]
# ### Assessing Data

# %%
#assessing Data
#-tidak ada yang salah dengan jumlah data

customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
#untuk memastikan benar atau tidaknya terdapat missing values
#-aman

customers_df.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
#melihat duplikasi data
#-aman

print("Jumlah duplikasi: ", customers_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
#menampilkan ringkasan parameter statistik

customers_df.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %%
#menilai data orders
#*terdapat missing values
#*tipe data juga mungkin akan di ubah

orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
#mengecek apakah ada missing values, hasil menunjukkan ada
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
#tidak terdapat duplikasi
#-aman

print("Jumlah duplikasi: ",orders_df.duplicated().sum())
orders_df.describe()
# Out:
# Jumlah duplikasi:  0
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-08-02 12:05:26  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# ...

# %%
#menilai data product
#-terdapat missing values

product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
#mengecek apakah ada missing values, hasil menunjukkan ada
product_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
#cek duplikasi data
#-aman

print("Jumlah duplikasi: ", product_df.duplicated().sum())
 
product_df.describe()
# Out:
# Jumlah duplikasi:  0
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# ...

# %%
#menilai data sales/order_items
#-aman, tidak ada missing values
#*tipe data mungkin akan diubah

sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
#memastikan tidak ada missing values

sales_df.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
#cek duplikasi data
#-aman

print("Jumlah duplikasi: ", sales_df.duplicated().sum())
sales_df.describe()
# Out:
# Jumlah duplikasi:  0
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %% [markdown]
# **Insight:**
# - Berdasarkan hasil analisa, masih terdapat missing values dan tipe data tiap tabel
# - assessing data sangat membantu dalam membersihkan data-data seperti missing values, tipe data, duplikasi data dan inaccurate values

# %% [markdown]
# ### Cleaning Data

# %%
#CLEANING DATA

#1.pembersihan duplikat data = seluruh data tidak ada yang duplikat
#2.menangani missing values = orders=aman, product=aman,

# %%
#2

orders_df[orders_df.order_approved_at.isna()]
# Out:
#                                order_id                       customer_id  \
# 1130   00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1801   ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# 1868   df8282afe61008dc26c6c31011474d02  aa797b187b5466bc6925aaaa4bb3bed1
# 2029   8d4c637f1accf7a88a4555f02741e606  b1dd715db389a2077f43174e7a675d07
# 2161   7a9d4c7f9b068337875b95465330f2fc  7f71ae48074c0cfec9195f88fcbfac55
# ...                                 ...                               ...
# 97696  5a00b4d35edffc56b825c3646a99ba9d  6a3bdf004ca96338fb5fad1b8d93c2e6
# 98415  227c804e2a44760671a6a5697ea549e4  62e7477e75e542243ee62a0ba73f410f
# 98909  e49e7ce1471b4693482d40c2bd3ad196  e4e7ab3f449aeb401f0216f86c2104db
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
#
#       order_status order_purchase_timestamp order_approved_at  \
# ...

# %%
#menggunakan nilai yang dominan sebagai pengganti missing value

orders_df.order_approved_at.value_counts()
# Out:
# order_approved_at
# 2018-02-27 04:31:10    9
# 2017-11-07 07:30:38    7
# 2018-02-06 05:31:52    7
# 2017-12-05 10:30:42    7
# 2017-11-07 07:30:29    7
#                       ..
# 2018-02-04 14:50:22    1
# 2018-06-05 04:51:42    1
# 2017-11-26 10:36:06    1
# 2018-06-27 11:06:41    1
# 2017-07-09 22:10:13    1
# Name: count, Length: 90733, dtype: int64

# %%
orders_df.fillna(value="2018-02-27 04:31:10", inplace=True)

# %%
#cek untuk memastikan apakah masih terdapat missing value
#-aman
orders_df.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %%
#2
#-nilai kosong?
#-apakah karena pengosongan missing value dominan?

orders_df[orders_df.order_delivered_carrier_date.isna()]
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date]
# Index: []

# %%
#2
#-nilai kosong?
#-apakah karena pengosongan missing value dominan?

orders_df[orders_df.order_delivered_customer_date.isna()]
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date]
# Index: []

# %%
#2

product_df[product_df.product_category_name.isna()]
# Out:
#                              product_id product_category_name  \
# 105    a41e356c76fab66334f36de622ecbd3a                   NaN
# 128    d8dee61c2034d6d075997acef1870e9b                   NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154    46b48281eb6d663ced748f324108c733                   NaN
# 197    5fb61f482620cb672f5e586bb132eae9                   NaN
# ...                                 ...                   ...
# 32515  b0a0c5dd78e644373b199380612c350a                   NaN
# 32589  10dbe0fbaa2c505123c17fdc34a63c56                   NaN
# 32616  bd2ada37b58ae94cc838b9c0569fecd8                   NaN
# 32772  fa51e914046aab32764c41356b9d4ea4                   NaN
# 32852  c4ceee876c82b8328e9c293fa0e1989b                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                    NaN                         NaN                 NaN
# ...

# %%
#2
#menggunakan nilai yang dominan sebagai pengganti missing value

product_df.product_category_name.value_counts()
# Out:
# product_category_name
# cama_mesa_banho                  3029
# esporte_lazer                    2867
# moveis_decoracao                 2657
# beleza_saude                     2444
# utilidades_domesticas            2335
#                                  ...
# fashion_roupa_infanto_juvenil       5
# casa_conforto_2                     5
# pc_gamer                            3
# seguros_e_servicos                  2
# cds_dvds_musicais                   1
# Name: count, Length: 73, dtype: int64

# %%
#2
#menggunakan nilai yang dominan sebagai pengganti missing value

product_df.product_name_lenght.value_counts()
# Out:
# product_name_lenght
# 60.0    2182
# 59.0    2025
# 58.0    1887
# 57.0    1719
# 55.0    1683
#         ...
# 66.0       1
# 72.0       1
# 67.0       1
# 76.0       1
# 6.0        1
# Name: count, Length: 66, dtype: int64

# %%
#2
#menggunakan nilai yang dominan sebagai pengganti missing value

product_df.product_description_lenght.value_counts()
# Out:
# product_description_lenght
# 404.0     94
# 729.0     86
# 651.0     66
# 703.0     66
# 236.0     65
#           ..
# 3379.0     1
# 2545.0     1
# 2715.0     1
# 3295.0     1
# 3737.0     1
# Name: count, Length: 2960, dtype: int64

# %%
#2
#menggunakan nilai yang dominan sebagai pengganti missing value

product_df.product_photos_qty  .value_counts()
# Out:
# product_photos_qty
# 1.0     16489
# 2.0      6263
# 3.0      3860
# 4.0      2428
# 5.0      1484
# 6.0       968
# 7.0       343
# 8.0       192
# 9.0       105
# 10.0       95
# 11.0       46
# 12.0       35
# 13.0        9
# 15.0        8
# 17.0        7
# 14.0        5
# 18.0        2
# 20.0        1
# 19.0        1
# Name: count, dtype: int64

# %%
#2
#menggunakan nilai yang dominan sebagai pengganti missing value

product_df.product_weight_g.value_counts()
# Out:
# product_weight_g
# 200.0      2084
# 300.0      1561
# 150.0      1259
# 400.0      1206
# 100.0      1188
#            ...
# 1436.0        1
# 2174.0        1
# 5453.0        1
# 12783.0       1
# 16333.0       1
# Name: count, Length: 2204, dtype: int64

# %%
#2
#menggunakan nilai yang dominan sebagai pengganti missing value

product_df.product_length_cm.value_counts()
# Out:
# product_length_cm
# 16.0    5520
# 20.0    2816
# 30.0    2029
# 18.0    1502
# 25.0    1387
#         ...
# 96.0       4
# 10.0       3
# 8.0        2
# 9.0        2
# 7.0        1
# Name: count, Length: 99, dtype: int64

# %%
#2
#menggunakan nilai yang dominan sebagai pengganti missing value

product_df.product_height_cm.value_counts()
# Out:
# product_height_cm
# 10.0    2548
# 15.0    2022
# 20.0    1991
# 16.0    1595
# 11.0    1551
#         ...
# 98.0       2
# 97.0       2
# 99.0       1
# 89.0       1
# 94.0       1
# Name: count, Length: 102, dtype: int64

# %%
#2
#menggunakan nilai yang dominan sebagai pengganti missing value

product_df.product_width_cm.value_counts()
# Out:
# product_width_cm
# 11.0     3718
# 20.0     3053
# 16.0     2808
# 15.0     2393
# 30.0     1786
#          ...
# 103.0       1
# 118.0       1
# 97.0        1
# 77.0        1
# 104.0       1
# Name: count, Length: 95, dtype: int64

# %%
product_df.fillna(value="11.0", inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_21512\147672563.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '11.0' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   product_df.fillna(value="11.0", inplace=True)

# %%
#missing value berhasil
product_df.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %%
#MEMBERSIHKAN DATA / CLEANING DATA

# %%
#mengubah tipe data orders menjadi date time

datetime_columns = ["order_purchase_timestamp", "order_approved_at", "order_delivered_carrier_date", "order_delivered_customer_date", "order_estimated_delivery_date"]
 
for column in datetime_columns:
  orders_df[column] = pd.to_datetime(orders_df[column])

# %%
#cek apakah sudah berubah
#-aman

orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99441 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   99441 non-null  datetime64[ns]
#  6   order_delivered_customer_date  99441 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %%
#mengubah tipe data sales menjadi date time

datetime_columns = ["shipping_limit_date"]
 
for column in datetime_columns:
  sales_df[column] = pd.to_datetime(sales_df[column])

# %%
#cek apakah sudah berubah
#-aman

sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %% [markdown]
# **Insight:**
# - Cleaning data membantu dalam pembersihan data kotor seperti missing values, tipe data, duplikasi data dan inaccurate values
# - cleaning data dapat membantu dalam menjalankan data sebagaimana mestinya

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
#EXPLORATORY DATA ANALYSIS

# %%
customers_df.describe(include="all")
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     274fa6071e5e17fe303b9748641082c8  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %%
#melihat demografi customers

# %%
#melihat persebaran jumlah pelanggan berdasarkan kota (city)
customers_df.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo             15540
# rio de janeiro         6882
# belo horizonte         2773
# brasilia               2131
# curitiba               1521
#                       ...
# ponto novo                1
# populina                  1
# porteiras                 1
# portela                   1
# pitanga de estrada        1
# Name: customer_id, Length: 4119, dtype: int64

# %%
# dan negara bagian (state)
customers_df.groupby(by="customer_state").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: customer_id, dtype: int64

# %%
#Eksplorasi Data orders_df
#membuat sebuah kolom baru untuk memuat waktu pengiriman tiap order

delivery_time = orders_df["order_delivered_carrier_date"] - orders_df["order_delivered_customer_date"]
delivery_time = delivery_time.apply(lambda x: x.total_seconds())
orders_df["delivery_time"] = round(delivery_time/86400)

# %%
#ini akan menambahkan kolom baru yaitu "delivery time" pada orders
orders_df.describe(include="all")
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
# freq                                   1                                 1
# mean                                 NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
# std                                  NaN                               NaN
#
#        order_status       order_purchase_timestamp  \
# ...

# %%
#Eksplorasi Data orders_df dan customers_df
#mengidentifikasi pelanggan yang belum pernah melakukan order

customer_id_in_orders_df =  orders_df.customer_id.tolist()
customers_df["status"] = customers_df["customer_id"].apply(lambda x: "Active" if x in customer_id_in_orders_df else "Non Active")
customers_df.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 24273  91f2fe378f8c723cbdcc798e3164c9d4  0977cd50786b1f5d899cc3b93989acea
# 36815  59b7743e6f1ffb4c84050f7d6b295331  f81dab4af5a125ab52c4e530ee748493
# 75901  3231b84e6605fdf9e9d0a9fd4bc290e9  435615550ef4aa0b8e484c055a42808b
# 80501  b99655875e88535e49976ea21cb258a1  ecebb5627b6336378511917b54a81405
# 76136  365adfcd960eaab19ba5e79e34d30b03  97b7e420622142b94bae2465a7ea4423
#
#        customer_zip_code_prefix            customer_city customer_state  \
# 24273                     54360  jaboatao dos guararapes             PE
# 36815                     13456    santa barbara d'oeste             SP
# 75901                     88220                  itapema             SC
# 80501                     31525           belo horizonte             MG
# 76136                     66813                    belem             PA
#
#        status
# 24273  Active
# 36815  Active
# 75901  Active
# 80501  Active
# ...

# %%
#data menunjukkan bahwa pengguna adalah pelanggan aktif semua

customers_df.groupby(by="status").customer_id.count()
# Out:
# status
# Active    99441
# Name: customer_id, dtype: int64

# %%
#melakukan join dan merge

orders_customers_df = pd.merge(
    left=orders_df,
    right=customers_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
orders_customers_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
#Jumlah order berdasarkan kota

orders_customers_df.groupby(by="customer_city").order_id.nunique().sort_values(ascending=False).reset_index().head(10)
# Out:
#            customer_city  order_id
# 0              sao paulo     15540
# 1         rio de janeiro      6882
# 2         belo horizonte      2773
# 3               brasilia      2131
# 4               curitiba      1521
# 5               campinas      1444
# 6           porto alegre      1379
# 7               salvador      1245
# 8              guarulhos      1189
# 9  sao bernardo do campo       938

# %%
##Jumlah order berdasarkan state

orders_customers_df.groupby(by="customer_state").order_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: order_id, dtype: int64

# %%
#Eksplorasi Data product_df dan sales_df

# %%
product_df.describe(include="all")
# Out:
#                               product_id product_category_name  \
# count                              32951                 32951
# unique                             32951                    74
# top     106392145fca363410d287a815be6de4       cama_mesa_banho
# freq                                   1                  3029
#
#         product_name_lenght product_description_lenght  product_photos_qty  \
# count               32951.0                      32951             32951.0
# unique                 67.0                       2961                20.0
# top                    60.0                       11.0                 1.0
# freq                 2182.0                        610             16489.0
#
#         product_weight_g  product_length_cm  product_height_cm  \
# count            32951.0            32951.0            32951.0
# unique            2205.0              100.0              103.0
# top                200.0               16.0               10.0
# ...

# %%
sales_df.describe(include="all")
# Out:
#                                 order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# mean                                 NaN       1.197834
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# 50%                                  NaN       1.000000
# 75%                                  NaN       1.000000
# max                                  NaN      21.000000
# std                                  NaN       0.705124
#
#                               product_id                         seller_id  \
# count                             112650                            112650
# unique                             32951                              3095
# ...

# %%
#melihat harga produk yg termahal dan terendah

sales_df.sort_values(by="price", ascending=False)
# Out:
#                                 order_id  order_item_id  \
# 3556    0812eb902a67711a1cb742b3cdaa65ae              1
# 112233  fefacc66af859508bf1a7934eab1e97f              1
# 107841  f5136e38d1a14a4dbd87dff67da82701              1
# 74336   a96610ab360d42a2e5335a3998b4718a              1
# 11249   199af31afc78c699f0dbf71fb178d4d4              1
# ...                                  ...            ...
# 57304   8272b63d03f5f79c56e9e4120aec44ef              8
# 57297   8272b63d03f5f79c56e9e4120aec44ef              1
# 48625   6e864b3f0ec71031117ad4cf46b7f2a1              1
# 87081   c5bdd8ef3c0ec420232e668302179113              2
# 27652   3ee6513ae7ea23bdfab5b9ab60bffcb5              1
#
#                               product_id                         seller_id  \
# 3556    489ae2aa008f021502940f251d4cce7f  e3b4998c7a498169dc7bce44e6bb6277
# 112233  69c590f7ffc7bf8db97190b6cb6ed62e  80ceebb4ee9b31afb6c6a916a574a1e2
# ...

# %%
#sebelumnya terdapat error karena mungkin terdapat string dalam tipe data float atau sebaliknya, dilakukan mengubah tipe data kolom menjadi numerik.
#Jika ada nilai yang tidak valid, akan diganti dengan NaN

product_df["product_length_cm"] = pd.to_numeric(product_df["product_length_cm"], errors="coerce")
product_df["product_weight_g"] = pd.to_numeric(product_df["product_weight_g"], errors="coerce")

# %%
#Hapus baris dengan nilai tidak valid: Setelah konversi, nilai yang tidak valid akan menjadi NaN.

product_df = product_df.dropna(subset=["product_length_cm", "product_weight_g"])

# %%
#Setelah dilakukan menurut chatgpt, data dapat menampilkan pivot table nya

product_df.groupby(by="product_category_name").agg({
    "product_id": "nunique",
    "product_length_cm": "sum",
    "product_weight_g":  ["min", "max"]
})
# Out:
#                           product_id product_length_cm product_weight_g  \
#                              nunique               sum              min
# product_category_name
# 11.0                             610           17501.0             11.0
# agro_industria_e_comercio         74            2703.0             50.0
# alimentos                         82            1746.0             75.0
# alimentos_bebidas                104            2434.0             50.0
# artes                             55            1976.0            100.0
# ...                              ...               ...              ...
# sinalizacao_e_seguranca           93            2837.0            100.0
# tablets_impressao_imagem           9             253.0            100.0
# telefonia                       1134           20903.0             50.0
# telefonia_fixa                   116            2395.0             50.0
# utilidades_domesticas           2335           74393.0             50.0
#
#
# ...

# %%
#untuk mengetahui produk yang laris dengan melakukan merge tabel product_df dan sales_df
sales_product_df = pd.merge(
    left=sales_df,
    right=product_df,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
sales_product_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value product_category_name  \
# 0 2017-09-19 09:45:35   58.90          13.29            cool_stuff
# 1 2017-05-03 11:05:13  239.90          19.93              pet_shop
# ...

# %%
#melihat informasi penjualan produk berdasarkan tipenya

sales_product_df.groupby(by="product_category_name").agg({
    "order_id": "nunique",
    "freight_value": "sum",
    "price": "sum"
})
# Out:
#                            order_id  freight_value      price
# product_category_name
# 11.0                           1451       28169.81  179535.28
# agro_industria_e_comercio       182        5843.60   72530.47
# alimentos                       450        7271.03   29393.41
# alimentos_bebidas               227        4507.99   15179.48
# artes                           202        4045.17   24202.64
# ...                             ...            ...        ...
# sinalizacao_e_seguranca         140        6507.82   21509.23
# tablets_impressao_imagem         79        1226.20    7528.41
# telefonia                      4199       71215.79  323667.53
# telefonia_fixa                  217        4637.81   59583.00
# utilidades_domesticas          5884      146149.11  632248.66
#
# [74 rows x 3 columns]

# %%
#Eksplorasi DATA all_df

# %%
#membuat sebuah DataFrame baru bernama all_df untuk menampung semua informasi dari keempat tabel yang kita miliki

all_df = pd.merge(
    left=sales_product_df,
    right=orders_customers_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
all_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value product_category_name  \
# 0 2017-09-19 09:45:35   58.90          13.29            cool_stuff
# 1 2017-05-03 11:05:13  239.90          19.93              pet_shop
# ...

# %%
#melihat selera pembelian berdasarkan customer state dan kategori produk

all_df.groupby(by=["customer_city", "product_category_name"]).agg({
    "freight_value": "sum",
    "price": "sum"
})
# Out:
#                                             freight_value   price
# customer_city       product_category_name
# abadia dos dourados cool_stuff                      20.63  199.00
#                     esporte_lazer                   15.59  120.00
#                     livros_interesse_geral          18.38   39.90
# abadiania           eletroportateis                 75.53  949.99
# abaete              11.0                            13.37   36.90
# ...                                                   ...     ...
# ze doca             esporte_lazer                   38.60  149.90
#                     ferramentas_jardim              26.61   39.90
#                     instrumentos_musicais           49.04  359.00
# zortea              11.0                            16.79   29.90
#                     informatica_acessorios          20.98   69.90
#
# [25723 rows x 2 columns]

# %% [markdown]
# **Insight:**
# - Exploratory data analysis membantu dalam menentukan pertanyaan bisnis dalam permasalahan
# - dengan adanya exploratory analysis dapat membantu dalam meng evaluasi item atau produk apa saja yang dijual dan habit dari customer seperti barang apa yang sering dibeli dan dicari.

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Bagaimana performa penjualan dan revenue perusahaan dalam beberapa bulan terakhir?

# %%
#Melihat total order per bulan berdasarkan dari bulan 10 tahun 2016 hingga bulan 10 tahun 2018

monthly_orders_df = all_df.resample(rule='ME', on='order_purchase_timestamp').agg({
    "order_id": "nunique",
    "price": "sum"
})
monthly_orders_df = monthly_orders_df.sort_index()
 
monthly_orders_df = monthly_orders_df.reset_index()
monthly_orders_df.rename(columns={
    "order_id": "order_count",
    "price": "revenue"
}, inplace=True)
 
plt.figure(figsize=(10, 5)) 
plt.plot(monthly_orders_df["order_purchase_timestamp"], monthly_orders_df["order_count"], marker='o', linewidth=2, color="#72BCD4") 
plt.title("Number of Orders per Month (2016-2018)", loc="center", fontsize=20) 
plt.xticks(fontsize=10) 
plt.yticks(fontsize=10) 
plt.show()

# %%
#Melihat total revenue per bulan berdasarkan dari bulan 10 tahun 2016 hingga bulan 10 tahun 2018

plt.figure(figsize=(10, 5))
plt.plot(
    monthly_orders_df["order_purchase_timestamp"],
    monthly_orders_df["revenue"],
    marker='o', 
    linewidth=2,
    color="#72BCD4"
)
plt.title("Total Revenue per Month (2016-2018)", loc="center", fontsize=20)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# ### Pertanyaan 2: Produk apa yang paling mahal dan paling murah, sekaligus dengan penjualan terbaik dan terburuk?

# %%
#membuat data frame terbaru untuk Produk Apa yang Paling mahal dan Paling murah?

sum_order_items_df = all_df.groupby("product_category_name").price.sum().sort_values(ascending=False).reset_index()
sum_order_items_df.head(15)
# Out:
#      product_category_name       price
# 0             beleza_saude  1258681.34
# 1       relogios_presentes  1205005.68
# 2          cama_mesa_banho  1036988.68
# 3            esporte_lazer   988048.97
# 4   informatica_acessorios   911954.32
# 5         moveis_decoracao   729762.49
# 6               cool_stuff   635290.85
# 7    utilidades_domesticas   632248.66
# 8               automotivo   592720.11
# 9       ferramentas_jardim   485256.46
# 10              brinquedos   483946.60
# 11                   bebes   411764.89
# 12              perfumaria   399124.87
# 13               telefonia   323667.53
# 14       moveis_escritorio   273960.70

# %%
#Melihat penjualan terbaik dan terburuk

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))
 
colors = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]
 
sns.barplot(x="price", y="product_category_name", data=sum_order_items_df.head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Best Performing Product", loc="center", fontsize=15)
ax[0].tick_params(axis ='y', labelsize=12)
 
sns.barplot(x="price", y="product_category_name", data=sum_order_items_df.sort_values(by="price", ascending=True).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Worst Performing Product", loc="center", fontsize=15)
ax[1].tick_params(axis='y', labelsize=12)
 
plt.suptitle("Best and Worst Performing Product by Number of Sales", fontsize=20)
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_21512\1921402241.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="price", y="product_category_name", data=sum_order_items_df.head(5), palette=colors, ax=ax[0])
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_21512\1921402241.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="price", y="product_category_name", data=sum_order_items_df.sort_values(by="price", ascending=True).head(5), palette=colors, ax=ax[1])

# %% [markdown]
# ### Pertanyaan 3: Pelanggan dari kota mana yang sering belanja?

# %%
# Mengelompokkan dan menghitung top 5 jumlah customer per kota
bystate_df = all_df.groupby(by="customer_city").customer_id.nunique().reset_index()

# Mengganti nama kolom agar lebih jelas
bystate_df.rename(columns={
    "customer_id": "customer_count"
}, inplace=True)

# Mengambil 5 customer city teratas berdasarkan customer_count
top_cities_df = bystate_df.sort_values(by="customer_count", ascending=False).head(10)

# Visualisasi data
plt.figure(figsize=(10, 5))
colors_ = ["#72BCD4", "#FF6347", "#FFD700", "#ADFF2F", "#00CED1"]  # Warna untuk 5 kota teratas
sns.barplot(
    x="customer_count", 
    y="customer_city",
    data=top_cities_df,
    palette=colors_
)

# Menambahkan judul dan label
plt.title("Top 5 Customer Cities", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='y', labelsize=12)
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_21512\617964634.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_21512\617964634.py:15: UserWarning:
# The palette list has fewer values (5) than needed (10) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(

# %% [markdown]
# ### Pertanyaan 4: Berapa banyak uang yang dihabiskan pelanggan dalam beberapa bulan terakhir?

# %%
#Melakukan RFM

rfm_df = all_df.groupby(by="customer_state", as_index=False).agg({
    "order_purchase_timestamp": "max", # mengambil tanggal order terakhir
    "order_id": "nunique", # menghitung jumlah order
    "price": "sum" # menghitung jumlah revenue yang dihasilkan
})
rfm_df.columns = ["customer_state", "max_order_timestamp", "frequency", "monetary"]
 
# menghitung kapan terakhir pelanggan melakukan transaksi (hari)
rfm_df["max_order_timestamp"] = rfm_df["max_order_timestamp"].dt.date
recent_date = orders_df["order_purchase_timestamp"].dt.date.max()
rfm_df["recency"] = rfm_df["max_order_timestamp"].apply(lambda x: (recent_date - x).days)
 
rfm_df.drop("max_order_timestamp", axis=1, inplace=True)
rfm_df.head()
# Out:
#   customer_state  frequency   monetary  recency
# 0             AC         81   15982.95       57
# 1             AL        411   80314.81       63
# 2             AM        147   22356.84       64
# 3             AP         68   13474.30       62
# 4             BA       3358  511349.99       57

# %%
#Melakukan RFM analysis atau mengelompokkan pelanggan ke dalam beberapa kategori yaitu recency, frequency, dan monetary.

fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(30, 6))
 
colors = ["#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4"]
 
sns.barplot(y="recency", x="customer_state", data=rfm_df.sort_values(by="recency", ascending=True).head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("By Recency (days)", loc="center", fontsize=18)
ax[0].tick_params(axis ='x', labelsize=15)
 
sns.barplot(y="frequency", x="customer_state", data=rfm_df.sort_values(by="frequency", ascending=False).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].set_title("By Frequency", loc="center", fontsize=18)
ax[1].tick_params(axis='x', labelsize=15)
 
sns.barplot(y="monetary", x="customer_state", data=rfm_df.sort_values(by="monetary", ascending=False).head(5), palette=colors, ax=ax[2])
ax[2].set_ylabel(None)
ax[2].set_xlabel(None)
ax[2].set_title("By Monetary", loc="center", fontsize=18)
ax[2].tick_params(axis='x', labelsize=15)
 
plt.suptitle("Best Customer Based on RFM Parameters (Customer State)", fontsize=20)
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_21512\3746341561.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="recency", x="customer_state", data=rfm_df.sort_values(by="recency", ascending=True).head(5), palette=colors, ax=ax[0])
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_21512\3746341561.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="frequency", x="customer_state", data=rfm_df.sort_values(by="frequency", ascending=False).head(5), palette=colors, ax=ax[1])
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_21512\3746341561.py:19: FutureWarning:
#
# ...

# %% [markdown]
# **Insight:**
# - Berdasarkan hasil analisis 1, penjualan cukup stabil di tahun 2017 dengan 200-400 total order dan mengalami peningkatan signnifikan di tahun 2018 mencapai 1000-1200 selama satu bulan, dan setelah itu penjualan kembali stabil seperti 2017 di 200-400 total order
# - Berdasarkan hasil analisis 2, beleza saude menjadi produk terbaik dan seguro e servicos menjadi terburuk
# - Berdasarkan hasil analisis 3, top 5 pelanggan yaitu berasal dari kota sao paolo, rio de janeiro, belo horizonte, brasilia dan curitiba yang mendominasi pasar Daffline
# -Berdasarkan hasil analisis 4, menggunakan RFM untuk melakukan segmentasi pelanggan (mengelompokkan pelanggan ke dalam beberapa kategori) berdasarkan tiga parameter, yaitu recency, frequency, dan monetary,

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Mengerjakan proyek analisis data pada Daffline cukup menantang, karena data yang banyak dapat diolah dengan baik untuk mengetahui bisnis apakah sejauh ini mengalami peningkatan atau kerugian
# - Dengan adanya visualisasi data, dapat memudahkan dalam membaca bagaimana bisnis penjualan berjalan dan grafik memudahkan dalam mebaca tren atau habit pada customer dan dapat mengetahui dari wilayah bagian mana pelanggan yang mendominasi pasar bisnis Daffline
